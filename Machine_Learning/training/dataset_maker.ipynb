# %%
import cv2
import os
import numpy as np
from PIL import Image
from pillow_heif import register_heif_opener

# Change the below to your directory containing your cube images
cube_image_dir = 'C:\\Users\\lucas\\Documents\\GitHub\\Plasma_Dragon_Charged_Up_Code\\Machine_Learning\\training\\Plasma_Dragon_Cube_dataset\\Cube'

# Change the below to your directory containing your non-cube images
non_cube_image_dir = 'C:\\Users\\lucas\\Documents\\GitHub\\Plasma_Dragon_Charged_Up_Code\\Machine_Learning\\training\\Plasma_Dragon_Cube_dataset\\Non-Cube'

# %%
# Convert all images to jpg (if necessary)
register_heif_opener()

# Janky converter code
os.chdir(cube_image_dir)
for file in os.listdir(cube_image_dir): 
    img = Image.open(file)
    file_name, file_ext = os.path.splitext(file)
    img.save(file_name+'.jpg')
    if file_ext != '.jpg':
        os.remove(cube_image_dir+'\\'+file_name+file_ext)

# Janky converter code
os.chdir(non_cube_image_dir)
for file in os.listdir(non_cube_image_dir): 
    img = Image.open(file)
    file_name, file_ext = os.path.splitext(file)
    img.save(file_name+'.jpg')
    if file_ext != '.jpg':
        os.remove(non_cube_image_dir+'\\'+file_name+file_ext)

# %%
#Convert all images to 96x96 grayscale in accordance with Pico4ML's camera
os.chdir(cube_image_dir)
for file in os.listdir(cube_image_dir):
    print(file)
    image = cv2.imread(os.path.join(os.curdir,file))
    print(image.shape)
    image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    print(image.shape)
    image = cv2.resize(image,[96,96])
    print(image.shape)
    cv2.imwrite(file,image)

os.chdir(non_cube_image_dir)
for file in os.listdir(non_cube_image_dir):
    print(file)
    image = cv2.imread(os.path.join(os.curdir,file))
    print(image.shape)
    image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    print(image.shape)
    image = cv2.resize(image,[96,96])
    print(image.shape)
    cv2.imwrite(file,image)
# Out:
# 20230628_185435.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# 20230628_185438.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# 20230628_185442.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# 20230628_185443.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# 20230628_185447.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# 20230628_185449.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# 20230628_185455.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# 20230628_185500.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# 20230628_185509.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# 20230701_094043.jpg
# (857, 642, 3)
# (857, 642)
# (96, 96)
# 20230701_095209.jpg
# (857, 642, 3)
# (857, 642)
# (96, 96)
# 20230701_095320.jpg
# (857, 1142, 3)
# (857, 1142)
# (96, 96)
# 20230701_103257.jpg
# (857, 1142, 3)
# (857, 1142)
# (96, 96)
# 20230701_103416.jpg
# (857, 642, 3)
# (857, 642)
# (96, 96)
# 20230701_103437.jpg
# (857, 642, 3)
# (857, 642)
# (96, 96)
# 20230701_103441.jpg
# (857, 642, 3)
# (857, 642)
# (96, 96)
# 20230701_103532.jpg
# (857, 642, 3)
# (857, 642)
# (96, 96)
# 20230701_103550.jpg
# (857, 642, 3)
# (857, 642)
# (96, 96)
# 20230701_103555.jpg
# (857, 642, 3)
# (857, 642)
# (96, 96)
# 20230701_103556.jpg
# (857, 642, 3)
# (857, 642)
# (96, 96)
# 20230701_103612.jpg
# (857, 1142, 3)
# (857, 1142)
# (96, 96)
# 20230701_103749.jpg
# (857, 1142, 3)
# (857, 1142)
# (96, 96)
# 20230701_111359.jpg
# (857, 1142, 3)
# (857, 1142)
# (96, 96)
# 20230701_111407.jpg
# (857, 1142, 3)
# (857, 1142)
# (96, 96)
# 20230701_115601.jpg
# (857, 1142, 3)
# (857, 1142)
# (96, 96)
# 20230701_115628.jpg
# (857, 1142, 3)
# (857, 1142)
# (96, 96)
# 20230701_120137.jpg
# (857, 1142, 3)
# (857, 1142)
# (96, 96)
# 20230701_121132.jpg
# (857, 1142, 3)
# (857, 1142)
# (96, 96)
# 20230701_121138.jpg
# (857, 1142, 3)
# (857, 1142)
# (96, 96)
# 20230701_121145.jpg
# (857, 642, 3)
# (857, 642)
# (96, 96)
# 20230701_121150.jpg
# (857, 642, 3)
# (857, 642)
# (96, 96)
# 20230701_121203.jpg
# (857, 642, 3)
# (857, 642)
# (96, 96)
# 20230701_121207.jpg
# (857, 642, 3)
# (857, 642)
# (96, 96)
# 20230701_121212.jpg
# (857, 642, 3)
# (857, 642)
# (96, 96)
# 20230701_121231.jpg
# (857, 1353, 3)
# (857, 1353)
# (96, 96)
# 20230701_121759.jpg
# (857, 1142, 3)
# (857, 1142)
# (96, 96)
# 20230701_122512.jpg
# (857, 1142, 3)
# (857, 1142)
# (96, 96)
# 20230701_122915.jpg
# (857, 1142, 3)
# (857, 1142)
# (96, 96)
# 20230701_122943.jpg
# (857, 642, 3)
# (857, 642)
# (96, 96)
# 20230701_123316.jpg
# (857, 1142, 3)
# (857, 1142)
# (96, 96)
# 20230701_123540.jpg
# (857, 1142, 3)
# (857, 1142)
# (96, 96)
# 20230701_123611.jpg
# (857, 1142, 3)
# (857, 1142)
# (96, 96)
# 20230701_124009.jpg
# (857, 1142, 3)
# (857, 1142)
# (96, 96)
# 20230701_125058.jpg
# (857, 1142, 3)
# (857, 1142)
# (96, 96)
# 20230701_125126.jpg
# (857, 1142, 3)
# (857, 1142)
# (96, 96)
# 20230701_125133.jpg
# (857, 1142, 3)
# (857, 1142)
# (96, 96)
# 20230701_130606.jpg
# (857, 642, 3)
# (857, 642)
# (96, 96)
# 20230701_130609.jpg
# (857, 642, 3)
# (857, 642)
# (96, 96)
# 20230701_130620.jpg
# (857, 642, 3)
# (857, 642)
# (96, 96)
# 20230701_130639.jpg
# (857, 642, 3)
# (857, 642)
# (96, 96)
# 20230701_130643.jpg
# (857, 642, 3)
# (857, 642)
# (96, 96)
# 20230701_130646.jpg
# (857, 642, 3)
# (857, 642)
# (96, 96)
# 20230701_132110.jpg
# (857, 1142, 3)
# (857, 1142)
# (96, 96)
# 20230701_132902.jpg
# (857, 642, 3)
# (857, 642)
# (96, 96)
# 20230701_132925.jpg
# (857, 642, 3)
# (857, 642)
# (96, 96)
# IMG_1140.jpg
# (4032, 3024, 3)
# (4032, 3024)
# (96, 96)
# IMG_1141.jpg
# (4032, 3024, 3)
# (4032, 3024)
# (96, 96)
# IMG_1142.jpg
# (4032, 3024, 3)
# (4032, 3024)
# (96, 96)
# IMG_1143.jpg
# (4032, 3024, 3)
# (4032, 3024)
# (96, 96)
# IMG_1144.jpg
# (4032, 3024, 3)
# (4032, 3024)
# (96, 96)
# IMG_1148.jpg
# (4032, 3024, 3)
# (4032, 3024)
# (96, 96)
# IMG_1149.jpg
# (4032, 3024, 3)
# (4032, 3024)
# (96, 96)
# IMG_1150.jpg
# (4032, 3024, 3)
# (4032, 3024)
# (96, 96)
# IMG_1151.jpg
# (4032, 3024, 3)
# (4032, 3024)
# (96, 96)
# IMG_1155.jpg
# (4032, 3024, 3)
# (4032, 3024)
# (96, 96)
# IMG_1156.jpg
# (4032, 3024, 3)
# (4032, 3024)
# (96, 96)
# IMG_1159.jpg
# (4032, 3024, 3)
# (4032, 3024)
# (96, 96)
# IMG_1161.jpg
# (4032, 3024, 3)
# (4032, 3024)
# (96, 96)
# IMG_1167.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# IMG_1168.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# IMG_1172.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# IMG_1173.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# IMG_1174.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# IMG_1175.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# IMG_1176.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# IMG_1179.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# IMG_1183.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# IMG_1184.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# IMG_1190.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# IMG_1191.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# IMG_1192.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# IMG_1194.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# IMG_1195.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# IMG_1196.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# IMG_1197.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# IMG_1201.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# IMG_1202.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# IMG_1203.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# IMG_1206.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# IMG_1207.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# IMG_1208.jpg
# (3024, 4032, 3)
# (3024, 4032)
# (96, 96)
# PXL_20230701_130802059.MP.jpg
# (857, 1142, 3)
# (857, 1142)
# (96, 96)
# PXL_20230701_135119134.MP.jpg
# (857, 1142, 3)
# (857, 1142)
# (96, 96)
# PXL_20230701_155404806.MP.jpg
# (857, 482, 3)
# (857, 482)
# (96, 96)
# PXL_20230701_160438813.jpg
# (857, 482, 3)
# (857, 482)
# (96, 96)
# PXL_20230701_163134874.jpg
# (857, 482, 3)
# (857, 482)
# (96, 96)
# PXL_20230701_163142871.jpg
# (857, 482, 3)
# (857, 482)
# (96, 96)
# PXL_20230701_165745649.jpg
# (857, 482, 3)
# (857, 482)
# (96, 96)
# PXL_20230701_165755028.jpg
# (857, 482, 3)
# (857, 482)
# (96, 96)
# PXL_20230701_165807075.jpg
# (857, 482, 3)
# (857, 482)
# (96, 96)
# PXL_20230701_165834551.jpg
# (857, 482, 3)
# (857, 482)
# (96, 96)
# PXL_20230701_165836484.jpg
# (857, 482, 3)
# (857, 482)
# (96, 96)
# PXL_20230701_165844600.jpg
# (857, 482, 3)
# (857, 482)
# (96, 96)
# PXL_20230701_165850949.jpg
# (857, 482, 3)
# (857, 482)
# (96, 96)
# PXL_20230701_165904147.jpg
# (857, 482, 3)
# (857, 482)
# (96, 96)
# PXL_20230701_165912960.jpg
# (857, 482, 3)
# (857, 482)
# (96, 96)
# PXL_20230701_165926145.jpg
# (857, 482, 3)
# (857, 482)
# (96, 96)
# PXL_20230701_165927930.jpg
# (857, 482, 3)
# (857, 482)
# (96, 96)
# PXL_20230701_170017521.jpg
# (857, 482, 3)
# (857, 482)
# (96, 96)
# PXL_20230701_170021390.jpg
# (857, 482, 3)
# (857, 482)
# (96, 96)
# VideoCapture_20230701-211225.jpg
# (857, 1142, 3)
# (857, 1142)
# (96, 96)
# VideoCapture_20230701